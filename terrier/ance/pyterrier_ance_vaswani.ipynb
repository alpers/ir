# %% [markdown]
# # PyTerrier ANCE Demo Notebook - Vaswani
#
# This notebook demonstrates use of [PyTerrier plugin for ANCE](https://github.com/terrierteam/pyterrier_ance) for dense passage retrieval.
#
# [ANCE](https://github.com/microsoft/ANCE) is a dense retrieval system leveraging single representations to encode documents and queries. ANCE does not require combination with sparse retrieval. ANCE leverages a training mechanism that constructs negatives from an Approximate Nearest Neighbor (ANN) index of the corpus, which is parallelly updated with the learning process to select more realistic negative training instances than the negative training instances selected by a sparse retrieval mechanism.
#
# ANCE is built on top of [BERT](https://arxiv.org/abs/1810.04805), and it nearly matches the accuracy of sparse retrieval and BERT reranking using dot-product in the ANCE-learned representation space and provides almost 100x speed-up.
#
# The corpus used in this demo is the [Vaswani NPL corpus](http://ir.dcs.gla.ac.uk/resources/test_collections/npl/), a corpus of 11,429 scientific abstract, with corresponding queries and relevance assessments.

# %% [markdown]
# ## Installation
#
# We need to install [PyTerrier](https://github.com/terrier-org/pyterrier).

# %%
# !pip install -q python-terrier

# %% [markdown]
# [ANCE](https://github.com/microsoft/ANCE) requires [FAISS](https://github.com/facebookresearch/faiss), a library for efficient similarity search and clustering of dense vectors.
#
# This is the setup for FAISS on Colab. YMMV outside of Colab.

# %%
# !apt install libomp-dev
# !pip install faiss
# Out:
# Unable to locate an executable at "/Library/Java/JavaVirtualMachines/openjdk-8.jdk/Contents/Home/bin/apt" (-1)
# Requirement already satisfied: faiss in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (1.7.1)
# Requirement already satisfied: numpy in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from faiss) (1.20.2)

# %% [markdown]
# This installs the [PyTerrier plugin for ANCE](https://github.com/terrierteam/pyterrier_ance). It supplies an indexer and a retrieval transformer. This also installs [ANCE](https://github.com/microsoft/ANCE).

# %%
# !pip install --upgrade git+https://github.com/seanmacavaney/pyterrier_ance.git@reranker
# Out:
# Collecting git+https://github.com/seanmacavaney/pyterrier_ance.git@reranker
#   Cloning https://github.com/seanmacavaney/pyterrier_ance.git (to revision reranker) to /private/var/folders/_l/bjhppdnd3k1_5g6bgx2p9mqw0000gn/T/pip-req-build-qyz10tua
#   Running command git clone -q https://github.com/seanmacavaney/pyterrier_ance.git /private/var/folders/_l/bjhppdnd3k1_5g6bgx2p9mqw0000gn/T/pip-req-build-qyz10tua
#   Running command git checkout -b reranker --track origin/reranker
#   Switched to a new branch 'reranker'
#   Branch 'reranker' set up to track remote branch 'reranker' from 'origin'.
# Collecting ANCE@ git+https://github.com/cmacdonald/ANCE.git
#   Cloning https://github.com/cmacdonald/ANCE.git to /private/var/folders/_l/bjhppdnd3k1_5g6bgx2p9mqw0000gn/T/pip-install-yvnwutkf/ance_c73f747fcab047b0bbbffc0ddf3d84bc
#   Running command git clone -q https://github.com/cmacdonald/ANCE.git /private/var/folders/_l/bjhppdnd3k1_5g6bgx2p9mqw0000gn/T/pip-install-yvnwutkf/ance_c73f747fcab047b0bbbffc0ddf3d84bc
# Requirement already satisfied: python-terrier>=0.5.0 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from pyterrier-ance==0.0.1) (0.6.0)
# Requirement already satisfied: pandas in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from pyterrier-ance==0.0.1) (1.2.5)
# Collecting transformers==2.3.0
#   Downloading transformers-2.3.0-py3-none-any.whl (447 kB)
#      |████████████████████████████████| 447 kB 230 kB/s eta 0:00:01     |█████████████████████████       | 348 kB 230 kB/s eta 0:00:01
# Collecting pytrec-eval
#   Downloading pytrec_eval-0.5.tar.gz (15 kB)
# Requirement already satisfied: wget in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from ANCE@ git+https://github.com/cmacdonald/ANCE.git->pyterrier-ance==0.0.1) (3.2)
# Collecting torch
#   Downloading torch-1.9.0-cp38-none-macosx_10_9_x86_64.whl (127.9 MB)
#      |████████████████████████████████| 127.9 MB 93 kB/s  eta 0:00:01    |█████████████████████▊          | 86.8 MB 1.5 MB/s eta 0:00:29     |█████████████████████▊          | 87.0 MB 1.5 MB/s eta 0:00:29     |██████████████████████▍         | 89.7 MB 1.3 MB/s eta 0:00:30     |█████████████████████████████▍  | 117.6 MB 1.2 MB/s eta 0:00:09     |█████████████████████████████▌  | 118.1 MB 1.2 MB/s eta 0:00:09
# Requirement already satisfied: tqdm in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from transformers==2.3.0->ANCE@ git+https://github.com/cmacdonald/ANCE.git->pyterrier-ance==0.0.1) (4.61.1)
# Collecting boto3
#   Downloading boto3-1.17.101-py2.py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 3.3 MB/s eta 0:00:01
# Collecting regex!=2019.12.17
#   Downloading regex-2021.4.4-cp38-cp38-macosx_10_9_x86_64.whl (284 kB)
#      |████████████████████████████████| 284 kB 1.6 MB/s eta 0:00:01
# Collecting sacremoses
#   Using cached sacremoses-0.0.45-py3-none-any.whl (895 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp38-cp38-macosx_10_6_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 1.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from transformers==2.3.0->ANCE@ git+https://github.com/cmacdonald/ANCE.git->pyterrier-ance==0.0.1) (1.20.2)
# Requirement already satisfied: requests in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from transformers==2.3.0->ANCE@ git+https://github.com/cmacdonald/ANCE.git->pyterrier-ance==0.0.1) (2.25.1)
# Requirement already satisfied: deprecation in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-ance==0.0.1) (2.1.0)
# Requirement already satisfied: statsmodels in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-ance==0.0.1) (0.12.2)
# Requirement already satisfied: ir-datasets>=0.3.2 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-ance==0.0.1) (0.4.0)
# Requirement already satisfied: pyjnius~=1.3.0 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-ance==0.0.1) (1.3.0)
# Requirement already satisfied: chest in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-ance==0.0.1) (0.2.3)
# Requirement already satisfied: scipy in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-ance==0.0.1) (1.7.0)
# Requirement already satisfied: ir-measures>=0.1.4 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-ance==0.0.1) (0.1.4)
# Requirement already satisfied: nptyping in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-ance==0.0.1) (1.4.2)
# Requirement already satisfied: jinja2 in /Users/alp/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-ance==0.0.1) (3.0.1)
# Requirement already satisfied: joblib in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-ance==0.0.1) (1.0.1)
# Requirement already satisfied: matchpy in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-ance==0.0.1) (0.5.4)
# Requirement already satisfied: more-itertools in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-ance==0.0.1) (8.8.0)
# Requirement already satisfied: sklearn in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-ance==0.0.1) (0.0)
# Requirement already satisfied: ijson>=3.1.3 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (3.1.4)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (5.4.1)
# Requirement already satisfied: lxml>=4.5.2 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (4.6.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (0.1.3)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (4.9.3)
# Requirement already satisfied: lz4>=3.1.1 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (3.1.3)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (2.5.4)
# Requirement already satisfied: warc3-wet>=0.2.3 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (0.2.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (2.2.1)
# Requirement already satisfied: pytrec-eval-terrier==0.5.1 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from ir-measures>=0.1.4->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (0.5.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from pandas->pyterrier-ance==0.0.1) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/alp/.local/lib/python3.8/site-packages (from pandas->pyterrier-ance==0.0.1) (2.8.1)
# Requirement already satisfied: six>=1.7.0 in /Users/alp/.local/lib/python3.8/site-packages (from pyjnius~=1.3.0->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (1.16.0)
# Requirement already satisfied: cython in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from pyjnius~=1.3.0->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (0.29.23)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers==2.3.0->ANCE@ git+https://github.com/cmacdonald/ANCE.git->pyterrier-ance==0.0.1) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers==2.3.0->ANCE@ git+https://github.com/cmacdonald/ANCE.git->pyterrier-ance==0.0.1) (1.26.6)
# Requirement already satisfied: idna<3,>=2.5 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers==2.3.0->ANCE@ git+https://github.com/cmacdonald/ANCE.git->pyterrier-ance==0.0.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers==2.3.0->ANCE@ git+https://github.com/cmacdonald/ANCE.git->pyterrier-ance==0.0.1) (2021.5.30)
# Requirement already satisfied: cbor>=1.0.0 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (1.0.0)
# Collecting s3transfer<0.5.0,>=0.4.0
#   Downloading s3transfer-0.4.2-py2.py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 1.6 MB/s eta 0:00:01
# Collecting botocore<1.21.0,>=1.20.101
#   Downloading botocore-1.20.101-py2.py3-none-any.whl (7.7 MB)
#      |████████████████████████████████| 7.7 MB 1.7 MB/s eta 0:00:01
# Collecting jmespath<1.0.0,>=0.7.1
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: heapdict in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from chest->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (1.0.1)
# Requirement already satisfied: packaging in /Users/alp/.local/lib/python3.8/site-packages (from deprecation->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (20.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alp/.local/lib/python3.8/site-packages (from jinja2->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (2.0.1)
# Requirement already satisfied: multiset<3.0,>=2.0 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from matchpy->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (2.1.1)
# Requirement already satisfied: typish>=1.7.0 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from nptyping->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (1.9.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/alp/.local/lib/python3.8/site-packages (from packaging->deprecation->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (2.4.7)
# Requirement already satisfied: click in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from sacremoses->transformers==2.3.0->ANCE@ git+https://github.com/cmacdonald/ANCE.git->pyterrier-ance==0.0.1) (8.0.1)
# Requirement already satisfied: scikit-learn in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from sklearn->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (0.24.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (2.1.0)
# Requirement already satisfied: patsy>=0.5 in /Users/alp/opt/anaconda3/lib/python3.8/site-packages (from statsmodels->python-terrier>=0.5.0->pyterrier-ance==0.0.1) (0.5.1)
# Collecting typing-extensions
#   Using cached typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Building wheels for collected packages: pyterrier-ance, ANCE, pytrec-eval
#   Building wheel for pyterrier-ance (setup.py) ... done
#   Created wheel for pyterrier-ance: filename=pyterrier_ance-0.0.1-py3-none-any.whl size=5521 sha256=1e2ca2fec783df7d4e0c5f0615cb6c8339264ab672191c5a2b04b5b1c5ea9585
#   Stored in directory: /private/var/folders/_l/bjhppdnd3k1_5g6bgx2p9mqw0000gn/T/pip-ephem-wheel-cache-w3i00ma6/wheels/f3/99/14/270f46700f5f46f42065ab17b0376efd0fbc6b8e9b778750c4
#   Building wheel for ANCE (setup.py) ... done
#   Created wheel for ANCE: filename=ANCE-0.1.0-py3-none-any.whl size=62203 sha256=25dac43b8f87dc024ebf9f68c8bedb6042c66713ba668feefae30200cb6bfe53
#   Stored in directory: /private/var/folders/_l/bjhppdnd3k1_5g6bgx2p9mqw0000gn/T/pip-ephem-wheel-cache-w3i00ma6/wheels/da/1c/fe/93ade445f6d42c8cc97b91d2dc5919d8f97f206fb271dd2d99
#   Building wheel for pytrec-eval (setup.py) ... done
#   Created wheel for pytrec-eval: filename=pytrec_eval-0.5-cp38-cp38-macosx_10_9_x86_64.whl size=71738 sha256=ff2cd00f21099dfac08573448d73f9a9b46288793f12fabc7fd83d57271c83a9
#   Stored in directory: /Users/alp/Library/Caches/pip/wheels/65/5a/e7/115104a6d6ebacea7cbd7434fdba04bd06b6756820994a326e
# Successfully built pyterrier-ance ANCE pytrec-eval
# Installing collected packages: jmespath, botocore, s3transfer, regex, typing-extensions, sentencepiece, sacremoses, boto3, transformers, torch, pytrec-eval, ANCE, pyterrier-ance
# Successfully installed ANCE-0.1.0 boto3-1.17.101 botocore-1.20.101 jmespath-0.10.0 pyterrier-ance-0.0.1 pytrec-eval-0.5 regex-2021.4.4 s3transfer-0.4.2 sacremoses-0.0.45 sentencepiece-0.1.96 torch-1.9.0 transformers-2.3.0 typing-extensions-3.10.0.0

# %% [markdown]
# # Setup
#
# Lets get [PyTerrier](https://github.com/terrier-org/pyterrier) started. This will download the latest version of the [Terrier](http://terrier.org) IR platform.

# %%
import pyterrier as pt
pt.init(tqdm='notebook')
# Out:
# PyTerrier 0.6.0 has loaded Terrier 5.5 (built by craigmacdonald on 2021-05-20 13:12)

# %% [markdown]
# We are using the [Vaswani dataset](http://ir.dcs.gla.ac.uk/resources/test_collections/npl/) – lets collect the topics & qrels.

# %%
dataset = pt.get_dataset("irds:vaswani")

# %% [markdown]
# This downloads the model checkpoint listed on the [ANCE github repository](https://github.com/microsoft/ANCE/#results). Download time can vary, on average it requires 11-12 minutes.

# %%
import os
if not os.path.exists("Passage_ANCE_FirstP_Checkpoint.zip"):
  # !wget https://webdatamltrainingdiag842.blob.core.windows.net/semistructstore/OpenSource/Passage_ANCE_FirstP_Checkpoint.zip
  # !unzip Passage_ANCE_FirstP_Checkpoint.zip
# Out:
# --2021-06-27 00:06:15--  https://webdatamltrainingdiag842.blob.core.windows.net/semistructstore/OpenSource/Passage_ANCE_FirstP_Checkpoint.zip
# Resolving webdatamltrainingdiag842.blob.core.windows.net (webdatamltrainingdiag842.blob.core.windows.net)... 52.239.193.68
# Connecting to webdatamltrainingdiag842.blob.core.windows.net (webdatamltrainingdiag842.blob.core.windows.net)|52.239.193.68|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1277112820 (1,2G) [application/octet-stream]
# Saving to: ‘Passage_ANCE_FirstP_Checkpoint.zip’
#
# Passage_ANCE_FirstP 100%[===================>]   1,19G   599KB/s    in 43m 21s
#
# 2021-06-27 00:49:37 (480 KB/s) - ‘Passage_ANCE_FirstP_Checkpoint.zip’ saved [1277112820/1277112820]
#
# Archive:  Passage_ANCE_FirstP_Checkpoint.zip
#    creating: Passage ANCE(FirstP) Checkpoint/
#   inflating: Passage ANCE(FirstP) Checkpoint/config.json
#   inflating: Passage ANCE(FirstP) Checkpoint/desktop.ini
#   inflating: Passage ANCE(FirstP) Checkpoint/merges.txt
#   inflating: Passage ANCE(FirstP) Checkpoint/optimizer.pt
#   inflating: Passage ANCE(FirstP) Checkpoint/pytorch_model.bin
#   inflating: Passage ANCE(FirstP) Checkpoint/scheduler.pt
#   inflating: Passage ANCE(FirstP) Checkpoint/special_tokens_map.json
#   inflating: Passage ANCE(FirstP) Checkpoint/tokenizer_config.json
#   inflating: Passage ANCE(FirstP) Checkpoint/training_args.bin
#   inflating: Passage ANCE(FirstP) Checkpoint/vocab.json

# %% [markdown]
# ## Indexing
#
# This indexes the [Vaswani dataset](http://ir.dcs.gla.ac.uk/resources/test_collections/npl/). Indexing takes about 3 minutes using a Colab GPU.

# %%
# !rm -rf ./anceindex

import pyterrier_ance
indexer = pyterrier_ance.ANCEIndexer(checkpoint_path="./Passage ANCE(FirstP) Checkpoint",
                                     index_path="./anceindex",
                                     num_docs=11429)
indexer.index(dataset.get_corpus_iter())
# Out:
# vaswani documents:   0%|          | 0/11429 [00:00<?, ?it/s]
# [INFO] loading configuration file ./Passage ANCE(FirstP) Checkpoint/config.json
# [INFO] Model config {
#   "_num_labels": 2,
#   "architectures": [
#     "RobertaDot_NLL_LN"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": 0,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": 2,
#   "eos_token_ids": 0,
#   "finetuning_task": "MSMarco",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-05,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 514,
#   "min_length": 0,
#   "model_type": "roberta",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 1,
#   "use_bfloat16": false,
#   "vocab_size": 50265
# }
#
# [INFO] Model name './Passage ANCE(FirstP) Checkpoint' not found in model shortcut name list (roberta-base, roberta-large, roberta-large-mnli, distilroberta-base, roberta-base-openai-detector, roberta-large-openai-detector). Assuming './Passage ANCE(FirstP) Checkpoint' is a path or url to a directory containing tokenizer files.
# [INFO] Didn't find file ./Passage ANCE(FirstP) Checkpoint/added_tokens.json. We won't load it.
# [INFO] loading file ./Passage ANCE(FirstP) Checkpoint/vocab.json
# [INFO] loading file ./Passage ANCE(FirstP) Checkpoint/merges.txt
# [INFO] loading file None
# [INFO] loading file ./Passage ANCE(FirstP) Checkpoint/special_tokens_map.json
# [INFO] loading file ./Passage ANCE(FirstP) Checkpoint/tokenizer_config.json
# [INFO] loading weights file ./Passage ANCE(FirstP) Checkpoint/pytorch_model.bin
# Using mean: False
# [INFO] Inference parameters <pyterrier_ance. object at 0x7fd43697dc40>
# Indexing:   0%|          | 0/11429 [00:00<?, ?d/s]
# Segment 0
# [INFO] ***** Running ANN Embedding Inference *****
# [INFO]   Batch size = 128
# Inferencing: 0it [00:00, ?it/s]
# Not running in distributed mode

# %% [markdown]
# We will not need the indexer anymore, so we free up some memory.

# %%
del(indexer)

# %% [markdown]
# The indexing procedure generates a number of [FAISS](https://github.com/facebookresearch/faiss) shards, together with some additional files.

# %%
# !ls /content/anceindex

# %% [markdown]
# # Retrieval
#
# Now that indexing has completed, we can load in the index and the checkpoint model (which we will need for encoding queries). Index loading can take some times, as the [FAISS](https://github.com/facebookresearch/faiss) shards need to be loaded in main memory.

# %%
ance_retr = pyterrier_ance.ANCERetrieval(checkpoint_path="/content/Passage ANCE(FirstP) Checkpoint",
                                        index_path="/content/anceindex")

# %% [markdown]
# Here we can ask [PyTerrier](https://github.com/terrier-org/pyterrier) to search the [ANCE](https://github.com/microsoft/ANCE) index for `'chemical reactions'`, returning the top 10 relevant documents.

# %%
(ance_retr % 10).search("chemical reactions")

# %% [markdown]
# # Running an Experiment

# %% [markdown]
# Lets prepare an experiment. Firstly, lets create in a BM25 baseline transformer.

# %%
bm25 = pt.BatchRetrieve(pt.get_dataset("vaswani").get_index(), wmodel="BM25")

# %% [markdown]
# You can also use ANCE as a text scorer (in a re-ranking setting). We'll compare with that baseline as well here.

# %%
ance_rerank = (bm25 % 100) >> pt.text.get_text(dataset, 'text') >> pyterrier_ance.ANCETextScorer(checkpoint_path="/content/Passage ANCE(FirstP) Checkpoint")

# %% [markdown]
# Finally, lets evaluate our performance. We also load in an BM25 index for the same corpus for comparison reasons.

# %%
pt.Experiment(
    [bm25, ance_rerank, ance_retr], 
    dataset.get_topics(), 
    dataset.get_qrels(), 
    eval_metrics=["map", "recip_rank", "mrt"],
    names=['BM25', 'BM25 >> ANCE Re-Rank', 'ANCE']
    )

# %% [markdown]
# So on this collection, ANCE isnt as effective under MAP or MRR (either as a ranker or a BM25 re-ranker), but the ranker does have a lower mean response time.
